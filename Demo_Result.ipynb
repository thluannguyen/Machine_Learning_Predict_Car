# %%
# Author: Nguyễn Thanh Luân
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
import datetime

import Regression_Model
import Classifier_Model 
import Clustering_Model 

import warnings 
warnings.filterwarnings('ignore')

# %%
detail = pd.read_excel('Car_Dataset.xlsx', sheet_name = 'Detail').drop('Unnamed: 0',axis=1)
detail
# Out:
#        Brand model  year  price transmission  mileage fuelType    tax   mpg  \
# 0       audi    A1  2017  12500       Manual    15735   Petrol  150.0  55.4
# 1       audi    A6  2016  16500    Automatic    36203   Diesel   20.0  64.2
# 2       audi    A1  2016  11000       Manual    29946   Petrol   30.0  55.4
# 3       audi    A4  2017  16800    Automatic    25952   Diesel  145.0  67.3
# 4       audi    A3  2019  17300       Manual     1998   Petrol  145.0  49.6
# ...      ...   ...   ...    ...          ...      ...      ...    ...   ...
# 108535    vw   Eos  2012   5990       Manual    74000   Diesel  125.0  58.9
# 108536    vw   Fox  2008   1799       Manual    88102   Petrol  145.0  46.3
# 108537    vw   Fox  2009   1590       Manual    70000   Petrol  200.0  42.0
# 108538    vw   Fox  2006   1250       Manual    82704   Petrol  150.0  46.3
# 108539    vw   Fox  2007   2295       Manual    74000   Petrol  145.0  46.3
#
#         engineSize
# 0              1.4
# ...

# %%
detail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108540 entries, 0 to 108539
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Brand         108540 non-null  object
#  1   model         108540 non-null  object
#  2   year          108540 non-null  int64
#  3   price         108540 non-null  int64
#  4   transmission  108540 non-null  object
#  5   mileage       108540 non-null  int64
#  6   fuelType      108540 non-null  object
#  7   tax           99187 non-null   float64
#  8   mpg           99187 non-null   float64
#  9   engineSize    108540 non-null  float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 8.3+ MB

# %%
detail.isnull().sum()/len(detail)*100
# Out:
# Brand           0.0000
# model           0.0000
# year            0.0000
# price           0.0000
# transmission    0.0000
# mileage         0.0000
# fuelType        0.0000
# tax             8.6171
# mpg             8.6171
# engineSize      0.0000
# dtype: float64

# %%
# drop or fill 
detail['tax'] = detail['tax'].fillna(detail['tax'].mean())
detail['mpg'] = detail['mpg'].fillna(detail['mpg'].mean())

# %%
detail.describe()
# Out:
#                 year          price        mileage            tax  \
# count  108540.000000  108540.000000  108540.000000  108540.000000
# mean     2017.098028   16890.124046   23025.928469     120.299838
# std         2.130057    9756.266820   21176.423684      60.368725
# min      1970.000000     450.000000       1.000000       0.000000
# 25%      2016.000000   10229.500000    7491.750000     120.299838
# 50%      2017.000000   14698.000000   17265.000000     145.000000
# 75%      2019.000000   20940.000000   32236.000000     145.000000
# max      2060.000000  159999.000000  323000.000000     580.000000
#
#                  mpg     engineSize
# count  108540.000000  108540.000000
# mean       55.166825       1.661644
# std        15.427517       0.557058
# min         0.300000       0.000000
# 25%        47.100000       1.200000
# 50%        55.166825       1.600000
# 75%        61.400000       2.000000
# max       470.800000       6.600000

# %%
plt.figure(figsize = (20, 10))
sns.countplot(detail.year)
plt.title('Distribution chart of the data about the year of vehicle production')
plt.show()

# %%
plt.figure(figsize = (20, 10))
sns.histplot(detail.price)
plt.title('Price distribution chart')
plt.show()

# %%
plt.figure(figsize = (20, 10))
sns.histplot(detail.mileage)
plt.title('Mileage distribution chart')
plt.show()

# %%
current_year = datetime.datetime.now().year
detail = detail[(detail.year <= current_year)]
len(detail)
# Out:
# 108539

# %% [markdown]
# ### Predict car price

# %%
df = detail.copy()
model = Regression_Model.LinearRegressionModel(df, method_scaler = 'minmax')
model.deploy()
# Out:
# Scaling Data....
# Please choose appropiate method!!
# Encoding Data....
# Spliting data after encoding data
# Remove Outlier....
# Data source have contain 10% record is outlier
# Split data for training-testing set....
# Select Feature....
# Training Data....
# Training model linear regression with method polynomial features.....
# ...
# MAE: 0.012920695659252222
# MSE: 0.000363903197280627
# RMSE: 0.019076246939076537
# R2-Square: 0.8451704311916868
# MAPE: 0.14098487920637248
# ...
# None

# %%
df = detail.copy()
model = Regression_Model.LinearRegressionModel(df)
model.deploy()
# Out:
# Scaling Data....
# Encoding Data....
# Spliting data after encoding data
# Remove Outlier....
# Data source have contain 10% record is outlier
# Split data for training-testing set....
# Select Feature....
# Training Data....
# Training model linear regression with method polynomial features.....
# ...
# MAE: 0.12822065360747262
# MSE: 0.02856414562339015
# RMSE: 0.1690093063218418
# R2-Square: 0.8696262675533993
# MAPE: 0.01219154726831167
# ...
# None

# %%
df = detail.copy()
model = Regression_Model.DecisionTreeRegressorModel(df)
model.deploy()
# Out:
# Scaling Data....
# Encoding Data....
# Spliting data after encoding data
# Remove Outlier....
# Data source have contain 10% record is outlier
# Split data for training-testing set....
# Training Data....
# ...
# MAE: 0.08495603426459757
# MSE: 0.015043951977449604
# RMSE: 0.12265378908720923
# R2-Square: 0.9375518320269454
# MAPE: 0.008083193984074708
# ...
# None

# %%
df = detail.copy()
model = Regression_Model.RandomForestRegressorModel(df)
model.deploy()
# Out:
# Scaling Data....
# Encoding Data....
# Spliting data after encoding data
# Remove Outlier....
# Data source have contain 10% record is outlier
# Split data for training-testing set....
# Training Data....
# ...
# MAE: 0.06912129589439864
# MSE: 0.009501574177744344
# RMSE: 0.09747601847502976
# R2-Square: 0.9594673504314077
# MAPE: 0.006578577009944534
# ...
# None

# %% [markdown]
# ### Clustering

# %%
df = detail.copy()
model = Clustering_Model.KMEAN(df, features = ['price', 'mileage', 'tax'])
model.deploy()
# Out:
# Scaling Data....
# Encoding Data....
# Remove Outlier....
# Data source have contain 10% record is outlier
# Select feature to training....
# Calculate number of cluster with elbow method
# Calculate number of cluster with sihouette scoring
# For n_clusters = 2 The average silhouette_score is : 0.3625899820069324
# For n_clusters = 3 The average silhouette_score is : 0.46157933482010527
# For n_clusters = 4 The average silhouette_score is : 0.4486337356130202
# For n_clusters = 5 The average silhouette_score is : 0.4740196189927554
# For n_clusters = 6 The average silhouette_score is : 0.4192602189847829
# For n_clusters = 7 The average silhouette_score is : 0.38985300962235353
# Training Data....
# Number of clusters: 5

# %%
df = detail.copy()
model = Clustering_Model.KMEAN(df, features = ['price', 'mileage', 'tax'], method_elbow = False, method_silhouete = False)
model.deploy()
# Out:
# Scaling Data....
# Encoding Data....
# Remove Outlier....
# Data source have contain 10% record is outlier
# Select feature to training....
# Training Data....
# Number of clusters: 6

# %%
df = detail.copy()
model = Clustering_Model.KMEAN(df, features = ['price', 'mileage', 'tax'], method_elbow = False, method_silhouete = False)
model.deploy()
# Out:
# Scaling Data....
# Encoding Data....
# Remove Outlier....
# Data source have contain 10% record is outlier
# Select feature to training....
# Training Data....
# Number of clusters: 3

# %%
### Test clustering with another scaler

# %%
df = detail.copy()
model = Clustering_Model.KMEAN(df, features = ['price', 'mileage', 'tax'], method_scaler = 'standard')
model.deploy()
# Out:
# Scaling Data....
# Please choose appropiate method!!
# Encoding Data....
# Remove Outlier....
# Data source have contain 10% record is outlier
# Select feature to training....
# Calculate number of cluster with elbow method
# Calculate number of cluster with sihouette scoring
# For n_clusters = 2 The average silhouette_score is : 0.48919799645194895
# For n_clusters = 3 The average silhouette_score is : 0.42290534785893524
# For n_clusters = 4 The average silhouette_score is : 0.4215049850660173
# For n_clusters = 5 The average silhouette_score is : 0.38449375738710184
# For n_clusters = 6 The average silhouette_score is : 0.36375534746525684
# For n_clusters = 7 The average silhouette_score is : 0.3542041678239571
# Training Data....
# Number of clusters: 4

# %% [markdown]
# ### Classifier decision

# %%
info = detail = pd.read_excel('Nhom08_Car.xlsx', sheet_name = 'Info').drop('Unnamed: 0',axis=1)
info
# Out:
#      buying_price maintenance_cost  doors persons lug_boot safety decision
# 0           vhigh            vhigh      2       2    small    med    unacc
# 1           vhigh            vhigh      2       2    small   high    unacc
# 2           vhigh            vhigh      2       2      med    low    unacc
# 3           vhigh            vhigh      2       2      med    med    unacc
# 4           vhigh            vhigh      2       2      med   high    unacc
# ...           ...              ...    ...     ...      ...    ...      ...
# 1722          low              low  5more    more      med    med     good
# 1723          low              low  5more    more      med   high    vgood
# 1724          low              low  5more    more      big    low    unacc
# 1725          low              low  5more    more      big    med     good
# 1726          low              low  5more    more      big   high    vgood
#
# [1727 rows x 7 columns]

# %%
info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1727 entries, 0 to 1726
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   buying_price      1727 non-null   object
#  1   maintenance_cost  1727 non-null   object
#  2   doors             1727 non-null   object
#  3   persons           1727 non-null   object
#  4   lug_boot          1727 non-null   object
#  5   safety            1727 non-null   object
#  6   decision          1727 non-null   object
# dtypes: object(7)
# memory usage: 94.6+ KB

# %%
for col in info.columns: 
    print(f"The {col.upper()}'s quantity chart")
    sns.countplot(info[col])
    plt.show()
# Out:
# The BUYING_PRICE's quantity chart
# The MAINTENANCE_COST's quantity chart
# The DOORS's quantity chart
# The PERSONS's quantity chart
# The LUG_BOOT's quantity chart
# The SAFETY's quantity chart
# The DECISION's quantity chart

# %%
df = info.copy()
model = Classifier_Model.DecisionTreeClassiferModel(df)
model.deploy()
# Out:
# Split data to feature and target...
# Encoding data...
# Split data for training-testing set....
# Training Data....
# Model evaluation...
# 0.9797687861271677
#               precision    recall  f1-score   support
#
#          acc       0.97      0.96      0.96        99
#         good       0.88      0.93      0.90        15
#        unacc       0.99      1.00      0.99       221
#        vgood       1.00      0.91      0.95        11
#
#     accuracy                           0.98       346
#    macro avg       0.96      0.95      0.95       346
# weighted avg       0.98      0.98      0.98       346
#
# [[ 95   2   2   0]
#  [  1  14   0   0]
#  [  1   0 220   0]
#  [  1   0   0  10]]

# %%
df = info.copy()
model = Classifier_Model.RandomForestClassifierModel(df)
model.deploy()
# Out:
# Split data to feature and target...
# Encoding data...
# Split data for training-testing set....
# Training Data....
# Model evaluation...
# 0.9682080924855492
#               precision    recall  f1-score   support
#
#          acc       0.95      0.94      0.94        99
#         good       0.75      1.00      0.86        12
#        unacc       0.99      0.98      0.98       225
#        vgood       1.00      1.00      1.00        10
#
#     accuracy                           0.97       346
#    macro avg       0.92      0.98      0.95       346
# weighted avg       0.97      0.97      0.97       346
#
# [[ 93   4   2   0]
#  [  0  12   0   0]
#  [  5   0 220   0]
#  [  0   0   0  10]]

# %%
df = info.copy()
model = Classifier_Model.CategoricalNBModel(df)
model.deploy()
# Out:
# Split data to feature and target...
# Encoding data...
# Split data for training-testing set....
# Training Data....
# Model evaluation...
# 0.8034682080924855
#               precision    recall  f1-score   support
#
#          acc       0.58      0.70      0.63        82
#         good       0.12      0.33      0.18         6
#        unacc       0.97      0.85      0.91       255
#        vgood       0.30      1.00      0.46         3
#
#     accuracy                           0.80       346
#    macro avg       0.49      0.72      0.55       346
# weighted avg       0.86      0.80      0.82       346
#
# [[ 57  12   6   7]
#  [  4   2   0   0]
#  [ 37   2 216   0]
#  [  0   0   0   3]]

# %%
df = info.copy()
model = Classifier_Model.KNNclfModel(df)
model.deploy()
# Out:
# Split data to feature and target...
# Encoding data...
# Split data for training-testing set....
# Selecting the appropriate parameter is in progress....
# Training Data....
# Number of neighbors: 8
# Choose a method for weight: distance
# Choose a method for calculate distance: 2
# Model evaluation...
# 0.9161849710982659
#               precision    recall  f1-score   support
#
#          acc       0.80      0.91      0.85        86
#         good       0.56      1.00      0.72         9
#        unacc       1.00      0.92      0.95       241
#        vgood       0.90      0.90      0.90        10
#
#     accuracy                           0.92       346
#    macro avg       0.81      0.93      0.86       346
# weighted avg       0.93      0.92      0.92       346
#
# [[ 78   6   1   1]
#  [  0   9   0   0]
#  [ 19   1 221   0]
#  [  1   0   0   9]]
